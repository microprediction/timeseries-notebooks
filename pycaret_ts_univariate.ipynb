# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/timeseries-notebooks/blob/main/pycaret_ts_univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall numpy 
# !pip install sktime

# %%
# !pip install pycaret-ts-alpha
# !pip install statsmodels
# !pip install git+https://github.com/microprediction/timemachines.git

# %% [markdown]
# ## Using Pycaret for univariate prediction
# Predict five steps ahead using median of the best three models pycaret finds

# %%
from timemachines.skaters.pycrt.pycaretwrapper import pycrt_iskater
import numpy as np 
y = np.random.randn(500)
x,x_std = pycrt_iskater(y=y,k=5)
print(x)
# Out:
#                                                              Model     MAE  \
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending  0.1141
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending  0.1099
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...  0.3253
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending  0.2373
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...   0.297
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending  0.1561
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...   0.204
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...  1.1089
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending  0.2042
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending  0.2042
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...  0.2042
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...  0.2052
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending   0.273
# theta                                             Theta Forecaster  0.2006
# ets                                                            ETS  0.2006
# exp_smooth                                   Exponential Smoothing  0.2006
# polytrend                              Polynomial Trend Forecaster  0.2006
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending  0.2734
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending  0.2736
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...  0.2736
# auto_arima                                              Auto ARIMA  0.1957
# naive                                             Naive Forecaster  1.2219
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending  0.9685
# snaive                                   Seasonal Naive Forecaster  1.2219
# arima                                                        ARIMA  0.2376
#
#                    RMSE    MAPE   SMAPE  TT (Sec)
# knn_cds_dt       0.1141  0.6078  0.8115    0.0933
# ada_cds_dt       0.1099  0.5412  0.8316    0.1333
# lightgbm_cds_dt  0.3253  1.5941  1.0607    0.0833
# rf_cds_dt        0.2373  1.1702  1.1902    0.4700
# gbr_cds_dt        0.297  1.4974  1.3663    0.1633
# et_cds_dt        0.1561  0.7936  1.4223    0.3033
# omp_cds_dt        0.204  1.0521  1.5377    0.0333
# par_cds_dt       1.1089  5.5892  1.7323    0.0300
# en_cds_dt        0.2042  1.0424  1.8619    0.0333
# lasso_cds_dt     0.2042  1.0424  1.8619    0.0300
# llar_cds_dt      0.2042  1.0424  1.8619    0.0267
# br_cds_dt        0.2052  1.0474  1.8625    0.0367
# huber_cds_dt      0.273  1.3872  1.9039    0.0300
# theta            0.2006  1.0245  1.9254    0.0233
# ets              0.2006  1.0245  1.9254    0.0600
# exp_smooth       0.2006  1.0244  1.9254    0.0500
# polytrend        0.2006  1.0245  1.9254    0.0133
# ridge_cds_dt     0.2734   1.387  1.9749    0.0300
# lr_cds_dt        0.2736  1.3878  1.9754    0.0300
# lar_cds_dt       0.2736  1.3878  1.9754    0.0300
# auto_arima       0.1957       1       2    0.9333
# naive            1.2219    5.97       2    0.0167
# dt_cds_dt        0.9685  5.0206       2    0.0367
# snaive           1.2219    5.97       2    0.0167
# arima            0.2376  1.2027       2    0.0567
# [0.06731448417271958, -0.5358661007676371, -0.17320787737031515, -0.25948731179715445, 0.2049738986927409]
